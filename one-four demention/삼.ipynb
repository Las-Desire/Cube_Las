# %%
import keras
import numpy as np
import matplotlib.pyplot as pp
# Out:
# D:\LLAS\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
x_shape=(50)
X=np.random.random(x_shape)
#평균
mean=np.random.randint(-100,100)
#표준정규
std=70

X=np.random.normal(mean,std,x_shape)

X=np.random.random(x_shape)*500-255
pp.plot(np.arange(0,50,1),X,"ro")

# %%
def random():
    return np.random.randint(-100,100)*np.random.random(1)
a=random()
b=random()
c=random()
d=random()

def f(x):
    return (a*x*3+1)*(b*x*2+10)*(c*x*2+2)
Y=f(X)
print(a,b)
pp.plot(X,Y,"ro")
# Out:
# [10.8732174] [-1.83049851]

# %%
model=keras.models.Sequential()
model.add(layer=keras.layers.Dense(10,input_shape=(1,)))
model.add(layer=keras.layers.Dense(20,activation='relu'))
model.add(layer=keras.layers.Dense(40,activation='relu'))
model.add(layer=keras.layers.Dense(80,activation='relu'))
model.add(layer=keras.layers.Dense(40,activation='relu'))
model.add(layer=keras.layers.Dense(20,activation='relu'))
model.add(layer=keras.layers.Dense(10,activation='relu'))
model.add(layer=keras.layers.Dense(1))

# %%
model.compile(loss=keras.losses.mean_absolute_error,optimizer='adam')
model.fit(X,Y,epochs=100000)
# Out:
# Epoch 1/100000
# 50/50 [==============================] - 1s 19ms/step - loss: 18183735992.3200
# Epoch 2/100000
# 50/50 [==============================] - 0s 90us/step - loss: 18183735050.2400
# Epoch 3/100000
# 50/50 [==============================] - 0s 120us/step - loss: 18183735296.0000
# Epoch 4/100000
# 50/50 [==============================] - 0s 110us/step - loss: 18183735459.8400
# Epoch 5/100000
# 50/50 [==============================] - 0s 100us/step - loss: 18183734886.4000
# Epoch 6/100000
# 50/50 [==============================] - 0s 140us/step - loss: 18183733985.2800
# Epoch 7/100000
# 50/50 [==============================] - 0s 100us/step - loss: 18183735787.5200
# Epoch 8/100000
# 50/50 [==============================] - 0s 130us/step - loss: 18183735050.2400
# Epoch 9/100000
# 50/50 [==============================] - 0s 100us/step - loss: 18183737262.0800
# Epoch 10/100000
# 50/50 [==============================] - 0s 120us/step - loss: 18183735541.7600
# ...

# %%
Y_=model.predict(X)
pp.plot(X,Y_,"ro")
